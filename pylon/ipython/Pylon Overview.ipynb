# %% [markdown]
# # Setup

# %%
# %pylab inline
# %run utilities.py

client = setup("rcaudle", "b09a645fe2f1fed748c12268fd473662")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Recordings

# %%
get_all()
# Out:
# [u'Music Example', u'2c0a5aea3c80a31f515045c62b115c56', u'stopped', 61363, 1427286738]
# [u'TV Series Explore', u'22fc4013b7f90551b4c26b77d6cb7025', u'stopped', 993101, 1427570733]
# [u'sdfsdf', u'b53ed09c3e061f88733c2d7da86b4572', u'stopped', 0, 1427284172]
# [u'Music Example v2', u'ca98ddab0c0b935dbcc794625a8f12d7', u'stopped', 0, 1427394398]
# [u'Music Example v3', u'922bb59b24b0bc8f1b81d0334857f0a5', u'stopped', 2458282, 1427394849]
# [u'City Explore v1', u'4f2348af10da81175bedc8868168e3dc', u'stopped', 115991, 1427459753]
# [u'Food Explore v1', u'9800ee8544c853b5df26fd2257ee40e0', u'stopped', 92762, 1427460420]
# [u'Example recording', u'684f1437b66e5870a3f564a3688976a2', u'stopped', 259, 1427283454]
# [u'The Masters v1', u'c4632deb4907e222cecadcaecf02b024', u'running', 2263499, 1427995171]
# [u'Top Gear v2', u'f721b29a45e82641e0e92b42de1c4313', u'stopped', 300277, 1427291881]
# [u'Automotive Demo', u'e69a5325b3777ebbbf82f15881e1144e', u'running', 1518534, 1428503667]
# ...

# %% [markdown]
# # Basic Analytics

# %%
hash = 'c4632deb4907e222cecadcaecf02b024'

# %%
plot_dashboard(hash,DASH_OVERVIEW)

# %%
age_gender_pyramid(hash,'fb.parent.topics.name',6, filter=' fb.parent.topics.name == "Masters Tournament" ')

# %% [markdown]
# # Topics

# %%
plot_freqDist(hash,'fb.parent.topics.name', 10)

# %%
freqDist(hash,'links.url', 5, filter=' fb.parent.topics.name == "Tiger Woods" ')

# %%
spam_csdl = '''tag.non_spam_sale 0.336973434597112 {fb.content contains_any "sale" or fb.parent.content contains_any "sale"}
tag.non_spam_sale 0.694614877883376 {fb.content contains_any "trade" or fb.parent.content contains_any "trade"}
tag.non_spam_sale -0.016319634970781 {fb.content contains_any "buy" or fb.parent.content contains_any "buy"}
tag.non_spam_sale 1.066136421386141 {fb.content contains_any "deposit" or fb.parent.content contains_any "deposit"}
tag.non_spam_sale 0.774793496833593 {fb.content contains_any "sell" or fb.parent.content contains_any "sell"}
tag.non_spam_sale -0.671717321050622 {fb.content contains_any "chance" or fb.parent.content contains_any "chance"}
tag.non_spam_sale 1.350330246083132 {fb.content contains_any "mint" or fb.parent.content contains_any "mint"}
tag.non_spam_sale 0.050426542286161 {fb.content contains_any "contact" or fb.parent.content contains_any "contact"}
tag.non_spam_sale -0.033343884614076 {fb.content contains_any "call" or fb.parent.content contains_any "call"}
tag.non_spam_sale -0.880582004944531 {fb.content contains_any "gift" or fb.parent.content contains_any "gift"}
tag.non_spam_sale -0.539732993755516 {fb.content contains_any "gift ideas" or fb.parent.content contains_any "gift ideas"}
tag.non_spam_sale -0.560411173712882 {fb.content contains_any "review" or fb.parent.content contains_any "review"}
tag.non_spam_sale 0.558448165415848 {fb.content contains_any "best price" or fb.parent.content contains_any "best price"}
tag.non_spam_sale 0.000000000000000 {fb.content contains_any "discount" or fb.parent.content contains_any "discount"}
tag.non_spam_sale 0.421561297927963 {fb.content contains_any "number" or fb.parent.content contains_any "number"}
tag.non_spam_sale 0.095484123243809 {fb.content contains_any "pm me" or fb.parent.content contains_any "pm me"}
tag.non_spam_sale 0.242873316252460 {fb.content contains_any "message me" or fb.parent.content contains_any "message me"}
tag.non_spam_sale 0.475931522677086 {fb.content contains_any "contact me" or fb.parent.content contains_any "contact me"}
tag.non_spam_sale -0.652950508857134 {fb.content contains_any "phone" or fb.parent.content contains_any "phone"}
tag.non_spam_sale 0.240502300939390 {fb.content contains_any "email" or fb.parent.content contains_any "email"}
tag.non_spam_sale 0.607758984139298 {fb.content contains_any "great condition" or fb.parent.content contains_any "great condition"}
tag.non_spam_sale 0.606113699871873 {fb.content contains_any "condition" or fb.parent.content contains_any "condition"}
tag.non_spam_sale 0.503601967182327 {fb.content contains_any "for sale" or fb.parent.content contains_any "for sale"}
tag.non_spam_sale 0.365839396957545 {fb.content contains_any "payments" or fb.parent.content contains_any "payments"}
tag.non_spam_sale -0.467534185025049 {fb.content contains_any "payment" or fb.parent.content contains_any "payment"}
tag.non_spam_sale -0.806018334804132 {fb.content contains_any "pay" or fb.parent.content contains_any "pay"}
tag.non_spam_sale -0.860535326230402 {fb.content contains_any "reviews" or fb.parent.content contains_any "reviews"}
tag.non_spam_sale 0.939303303219513 {fb.content contains_any "wtb" or fb.parent.content contains_any "wtb"}
tag.non_spam_sale 0.000000000000000 {fb.content contains_any "wts" or fb.parent.content contains_any "wts"}
tag.non_spam_sale -0.095826324294258 {fb.content contains_any "special" or fb.parent.content contains_any "special"}
tag.non_spam_sale 0.820024833314535 {fb.content contains_any "located in" or fb.parent.content contains_any "located in"}
tag.other -0.383526852468688 {fb.content contains_any "sale" or fb.parent.content contains_any "sale"}
tag.other -1.169380923788089 {fb.content contains_any "trade" or fb.parent.content contains_any "trade"}
tag.other -0.125093031952464 {fb.content contains_any "buy" or fb.parent.content contains_any "buy"}
tag.other -0.435845076779766 {fb.content contains_any "deposit" or fb.parent.content contains_any "deposit"}
tag.other 0.170634898816518 {fb.content contains_any "chance" or fb.parent.content contains_any "chance"}
tag.other -0.575692890889090 {fb.content contains_any "mint" or fb.parent.content contains_any "mint"}
tag.other 0.145586777066408 {fb.content contains_any "call" or fb.parent.content contains_any "call"}
tag.other -0.188554194307666 {fb.content contains_any "gift" or fb.parent.content contains_any "gift"}
tag.other 0.036871766531243 {fb.content contains_any "gift ideas" or fb.parent.content contains_any "gift ideas"}
tag.other -0.199496151757436 {fb.content contains_any "review" or fb.parent.content contains_any "review"}
tag.other -0.036320415290053 {fb.content contains_any "discount" or fb.parent.content contains_any "discount"}
tag.other -0.190345532739053 {fb.content contains_any "number" or fb.parent.content contains_any "number"}
tag.other 0.405059474299619 {fb.content contains_any "pm me" or fb.parent.content contains_any "pm me"}
tag.other -0.826502908054341 {fb.content contains_any "message me" or fb.parent.content contains_any "message me"}
tag.other 0.166605075547159 {fb.content contains_any "phone" or fb.parent.content contains_any "phone"}
tag.other -0.286787598162818 {fb.content contains_any "email" or fb.parent.content contains_any "email"}
tag.other -0.798560730816368 {fb.content contains_any "great condition" or fb.parent.content contains_any "great condition"}
tag.other -0.077210687626018 {fb.content contains_any "condition" or fb.parent.content contains_any "condition"}
tag.other -0.651536974255254 {fb.content contains_any "for sale" or fb.parent.content contains_any "for sale"}
tag.other -0.266352916688040 {fb.content contains_any "payments" or fb.parent.content contains_any "payments"}
tag.other -0.306181236055174 {fb.content contains_any "payment" or fb.parent.content contains_any "payment"}
tag.other 0.308030053485311 {fb.content contains_any "pay" or fb.parent.content contains_any "pay"}
tag.other 0.174007434454651 {fb.content contains_any "reviews" or fb.parent.content contains_any "reviews"}
tag.other -0.029656806483739 {fb.content contains_any "special" or fb.parent.content contains_any "special"}
tag.other -0.672111160514325 {fb.content contains_any "located in" or fb.parent.content contains_any "located in"}
tag.spam -0.021807617688121 {fb.content contains_any "trade" or fb.parent.content contains_any "trade"}
tag.spam 0.122265408375387 {fb.content contains_any "buy" or fb.parent.content contains_any "buy"}
tag.spam -0.406040918914267 {fb.content contains_any "deposit" or fb.parent.content contains_any "deposit"}
tag.spam -0.016257468216822 {fb.content contains_any "sell" or fb.parent.content contains_any "sell"}
tag.spam 0.045705906076719 {fb.content contains_any "chance" or fb.parent.content contains_any "chance"}
tag.spam -0.483977057953843 {fb.content contains_any "mint" or fb.parent.content contains_any "mint"}
tag.spam -0.075682769100166 {fb.content contains_any "call" or fb.parent.content contains_any "call"}
tag.spam 0.158304292167431 {fb.content contains_any "gift" or fb.parent.content contains_any "gift"}
tag.spam 0.458866742051546 {fb.content contains_any "review" or fb.parent.content contains_any "review"}
tag.spam -0.089829259424231 {fb.content contains_any "best price" or fb.parent.content contains_any "best price"}
tag.spam 0.030069483329294 {fb.content contains_any "discount" or fb.parent.content contains_any "discount"}
tag.spam -0.002764871541348 {fb.content contains_any "number" or fb.parent.content contains_any "number"}
tag.spam -0.420792619011430 {fb.content contains_any "pm me" or fb.parent.content contains_any "pm me"}
tag.spam 0.337892629910659 {fb.content contains_any "message me" or fb.parent.content contains_any "message me"}
tag.spam 0.085570859181141 {fb.content contains_any "contact me" or fb.parent.content contains_any "contact me"}
tag.spam -0.036479549516669 {fb.content contains_any "phone" or fb.parent.content contains_any "phone"}
tag.spam 0.105497399440560 {fb.content contains_any "email" or fb.parent.content contains_any "email"}
tag.spam -0.157396692307626 {fb.content contains_any "great condition" or fb.parent.content contains_any "great condition"}
tag.spam -0.158820956020983 {fb.content contains_any "condition" or fb.parent.content contains_any "condition"}
tag.spam -0.093120055031288 {fb.content contains_any "for sale" or fb.parent.content contains_any "for sale"}
tag.spam -0.476296063412843 {fb.content contains_any "payments" or fb.parent.content contains_any "payments"}
tag.spam 1.139483204623161 {fb.content contains_any "payment" or fb.parent.content contains_any "payment"}
tag.spam -0.039186237891100 {fb.content contains_any "pay" or fb.parent.content contains_any "pay"}
tag.spam 0.094514178256815 {fb.content contains_any "reviews" or fb.parent.content contains_any "reviews"}
tag.spam -0.535572822032024 {fb.content contains_any "wtb" or fb.parent.content contains_any "wtb"}
tag.spam 0.000000000000000 {fb.content contains_any "wts" or fb.parent.content contains_any "wts"}
tag.spam 0.053256628246948 {fb.content contains_any "special" or fb.parent.content contains_any "special"}
tag.spam -0.282262857808359 {fb.content contains_any "located in" or fb.parent.content contains_any "located in"}'''

# %%
client.pylon.compile(spam_csdl)
# Out:
# {u'created_at': datetime.datetime(2015, 4, 9, 16, 43, 7),
#  u'dpu': 2.0,
#  u'hash': u'1e54cbbb3c398956f56e218fffb6ec7f'}
